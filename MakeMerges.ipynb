# %%
# header
import pandas as pd
from GenerateLexDir import literal_eval_col
from FindBib import read_date

# %%
# load data
flexicon = pd.read_csv('FlexiconMERGE.csv', index_col='entry_id', keep_default_na=False)
merges = pd.read_csv('merge_matches.csv', index_col='entry_id', keep_default_na=False)

# %%
# take things literally
literal_eval_col(flexicon, 'note')
literal_eval_col(flexicon, 'other_sources')
literal_eval_col(flexicon, 'sense')
literal_eval_col(flexicon, 'these_vars')
literal_eval_col(flexicon, 'variant_of')

literal_eval_col(merges, 'matches')

# %%
# add a new column to merges to reflect exit status on entry pairs that couldn't be merge
merges.loc[:,'merge_error'] = ['']*len(merges)

# %%
# make a backup of flexicon
backup = flexicon.copy()

# %%
def get_bib(bib):
    bib = bib.lower()
    if "weir" in bib:
        return "Weir"
    
    elif "martins" in bib:
        return "Martins"
    
    elif "barbosa" in bib:
        return "Barbosa"
    
    elif "epps" in bib:
        if '18' in bib:
            return "Epps/Obert Fieldnotes 2018"
        elif '19' in bib:
            return "Epps/Obert Fieldnotes 2019"
        else:
            return None
    
    elif "sil" in bib:
        return "Sil Dict"
    
    else:
        return ''

# %%
# write method to compare entries and merge data automatically
# returns False to indicate that the entries could not be merged
def merge_entries(id1, id2):
    entry1 = flexicon.loc[id1]
    entry2 = flexicon.loc[id2]
    
    new_entry = dict()
    new_entry['other_sources'] = {}
    
    # bibliography & headword
    # probz most complicated
    bib1 = get_bib(entry1['bibliography'])
    bib2 = get_bib(entry2['bibliography'])
    
    if bib1 == bib2:
        new_entry['bibliography'] = bib1
        hdwd1 = entry1['headword'].strip()
        hdwd2 = entry2['headword'].strip()
        if hdwd1 == hdwd2:
            new_entry['headword'] = hdwd1
        else:    
            new_entry['headword'] = hdwd1 + ' %OR% ' + hdwd2
    elif 'Epps' in bib1:
        new_entry['bibliography'] = bib1
        new_entry['other_sources'][bib2] = entry2['headword']
        new_entry['headword'] = entry1['headword']
    elif 'Epps' in bib2:
        new_entry['bibliography'] = bib2
        new_entry['other_sources'][bib1] = entry1['headword']
        new_entry['headword'] = entry2['headword']
    else:
        return (False, 'Neither entry is from fieldnotes.')
    
    # date
    # prefer newer one
    date1 = entry1['date']
    date2 = entry2['date']
    new_entry['date'] = max(date1, date2)
    
    if entry1['date_modified']:
        new_entry['date_modified'] = entry1['date_modified']
    elif entry2['date_modified']:
        new_entry['date_modified'] = entry2['date_modified']
    else:
        new_entry['date_modified'] = new_entry['date']
        
    # motph_type
    # doesn't matter either
    new_entry['morph_type'] = entry1['morph_type']
    
    # note
    # try to merge keys into single dict
    # return False if have overlapping keys
    new_note = entry1['note'] if entry1['note'] else {}
    note2 = entry2['note'] if entry2['note'] else {}
    
    for k, v in note2.items():
        if k not in new_note:
            new_note[k] = v
        elif 'Predicted phonemic' in new_note[k]:
            new_note[k] = v
        elif 'Predicted phonemic' in v:
            pass
        elif new_note[k] == v:
            pass
        else:
            return (False, 'Note field has conflicting data.')
    new_entry['note'] = new_note
        
    # other_sources
    # ditto
    new_srcs = entry1['other_sources'] if entry1['other_sources'] else {}
    srcs2 = entry2['other_sources'] if entry2['other_sources'] else {}
    
    for k, v in srcs2.items():
        if k not in new_srcs:
            new_srcs[k] = v
        elif new_srcs[k] == v:
            pass
        else:
            return (False, 'other_sources field has conflicting data.')
    new_entry['other_sources'] = new_srcs
        
    # these_vars
    # same spiel
    new_vars = entry1['these_vars'] if entry1['these_vars'] else {}
    vars2 = entry2['these_vars'] if entry2['these_vars'] else {}
    
    for k, v in vars2.items():
        if k not in new_vars:
            new_vars[k] = v
        elif new_vars[k] == v:
            pass
        else:
            return (False, 'these_vars field has conflicting data.')
    new_entry['these_vars'] = new_vars
    
    # variant_of
    # keep on keepin' on
    new_varf = entry1['variant_of'] if entry1['variant_of'] else {}
    varf2 = entry2['variant_of'] if entry2['variant_of'] else {}
    
    for k, v in varf2.items():
        if k not in new_note:
            new_varf[k] = v
        elif new_varf[k] == v:
            pass
        else:
            return (False, 'variant_of field has conflicting data.')
        
    # sense
    # union of both lists
    new_entry['sense'] = entry1['sense']+entry2['sense']
    
    # pronunciation
    # preserve both if need be
    # I plan on cleaning pronunciation later
    pronc1 = entry1['pronunciation']
    pronc2 = entry2['pronunciation']
    if pronc1 and pronc2:
        new_entry['pronunciation'] = pronc1 + ' %OR% ' + pronc2
    elif pronc1:
        new_entry['pronunciation'] = pronc1
    elif pronc2:
        new_entry['pronunciation'] = pronc2
    else:
        new_entry['pronunciation'] = ''
        
    return new_entry

# %%
# use merge_entries function to merge entries
# (i'm sorry if you expected something else)

# start by making df w/ all merges that can be merged w/o extra steps
# (indicated by a note in the status col)
merges_to_merge = [x=='merge' for x in merges['status']]
merges_to_merge = merges[merges_to_merge]

for index, row in merges_to_merge.iterrows():
    result = None
    for id2 in row['matches'].keys():
        result = merge_entries(index, id2)
        if type(result) is tuple:
            break
        else:
            entry1 = result
    # take advantage of python's weird for-else syntax
    else:
        # success case
        print(entry1.keys())
        print( flexicon.columns )
        flexicon.loc[index] = entry1
        for id in row['matches'].keys():
            flexicon = flexicon.drop(id)
        merges = merges.drop(index)
        continue
    # failure case
    merges.at[index, 'merge_error'] = result[1]
# Out:
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')
# dict_keys(['other_sources', 'bibliography', 'headword', 'date', 'date_modified', 'morph_type', 'note', 'these_vars', 'sense', 'pronunciation'])
# Index(['bibliography', 'date', 'date_modified', 'headword', 'morph_type',
#        'note', 'other_sources', 'pronunciation', 'sense', 'these_vars',
#        'variant_of'],
#       dtype='object')

# %%
merges[merges['merge_error'] != '']
# Out:
#                                                                             def  \
# entry_id
# edṵ:k_1613de5c-4b41-4bc5-bfa47a967ead6a12                        pescar.zagaia
# erɛt_2370f1d5-42bf-477a-bec0cc27bf202069                           leave;deixar
# canana:_248cffb7-d6e2-42f6-b09ceee72262937c                        ?;lambe.olho
# wa:_36bdcbb1-66cb-47fc-a7ce1204359c2a62                             food;comida
# rṵ:ɲ_4ae8608d-42ec-4b15-b5f662cf14285129                  saltitar (iterativo)
# nu: me_5921bae6-4777-4444-be41a1db8d4ba21e                          times;vezes
# ji_5c846915-d6fc-437b-8c7d67cffc4f1363                              one;a.gente
# tʌ_5ea024ce-8d5b-461c-ae9697daffe5dbb1                              food;comida
# hẽɲ_63c8102a-b241-4712-a83870b21b5a086f                        to.dir;para.dir
# ra_691deaf6-11ec-4636-828c82636a8e4ead                                  3PL;3PL
# wapad_6d1f39e4-a447-4cba-b3ffb4b8f1eed9af                      piaba.fish;piaba
# mahaŋ_6da7140a-20bc-4055-a9dd9fe336967a75                         among;no.meio
# aʃo:p_fb0ac1ce-3487-4841-8c1e1d831b4bedca    {'asoop_fb0ac1ce-3487-4841-8c1e-1d831b4bedc9':...
# jajɛ_ff33ec40-692f-454d-915fee99245cc6f8     {'jajé     _ff33ec40-692f-454d-915f-ee99245cc6...
# eỹỹm2_b7f8608c-1aaa-4014-b04d-968cde2f7f87   {'eỹỹm1_db33bb76-0902-4cd5-a8db-eb1f7bdaefba':...
#
#                                                                    merge_error
# entry_id
# edṵ:k_1613de5c-4b41-4bc5-bfa47a967ead6a12   Neither entry is from fieldnotes.
# erɛt_2370f1d5-42bf-477a-bec0cc27bf202069     Neither entry is from fieldnotes.
# canana:_248cffb7-d6e2-42f6-b09ceee72262937c  Neither entry is from fieldnotes.
# wa:_36bdcbb1-66cb-47fc-a7ce1204359c2a62      Neither entry is from fieldnotes.
# rṵ:ɲ_4ae8608d-42ec-4b15-b5f662cf14285129    Neither entry is from fieldnotes.
# nu: me_5921bae6-4777-4444-be41a1db8d4ba21e   Neither entry is from fieldnotes.
# ji_5c846915-d6fc-437b-8c7d67cffc4f1363       Neither entry is from fieldnotes.
# tʌ_5ea024ce-8d5b-461c-ae9697daffe5dbb1       Neither entry is from fieldnotes.
# hẽɲ_63c8102a-b241-4712-a83870b21b5a086f     Neither entry is from fieldnotes.
# ra_691deaf6-11ec-4636-828c82636a8e4ead       Neither entry is from fieldnotes.
# wapad_6d1f39e4-a447-4cba-b3ffb4b8f1eed9af    Neither entry is from fieldnotes.
# mahaŋ_6da7140a-20bc-4055-a9dd9fe336967a75    Neither entry is from fieldnotes.
# karak_6f6f498f-e045-44a7-b814505bba4b8eb5    Neither entry is from fieldnotes.
# takə̰p_713254c9-c9a3-408e-89d8f85183abb1e9   Neither entry is from fieldnotes.
# go:r_78eea66c-9fe0-4ee5-a7ca79a089efa99a     Neither entry is from fieldnotes.
# aha_7b0d5ed4-7e8a-427a-a07d90a64f3094dc      Neither entry is from fieldnotes.
# naə:ɲ_8604bf25-763e-4f74-9f621229dc8c1306    Neither entry is from fieldnotes.
# nɛ hẽ_8b6c97f9-bff4-4755-a9b13d71dbc9938f   Neither entry is from fieldnotes.
# ʃo:_8d4ce206-887a-448d-a7db8239d7cbecd0      Neither entry is from fieldnotes.
# hado:_91228118-6e36-4bb1-8876c6ca8cf2491e    Neither entry is from fieldnotes.
# ʃa_9258a56c-b681-4637-922dc15c3cc4d778       Neither entry is from fieldnotes.
# adɨ:k_a8313ccc-413c-4657-b4ef14f1259891a4    Neither entry is from fieldnotes.
# iʃ_aabbc7a1-8b5c-4a46-a8f8348d31b31614       Neither entry is from fieldnotes.
# kapɨ̃:j_c53cf0e0-0078-4164-94672f4e98268e6e  Neither entry is from fieldnotes.
# aʃo:p_fb0ac1ce-3487-4841-8c1e1d831b4bedca    Neither entry is from fieldnotes.
# jajɛ_ff33ec40-692f-454d-915fee99245cc6f8     Neither entry is from fieldnotes.
# eỹỹm2_b7f8608c-1aaa-4014-b04d-968cde2f7f87    Note field has conflicting data.

# %%
print(backup.shape)
print(flexicon.shape)
# Out:
# (1579, 11)
# (1547, 11)

# %%
backup.to_csv('FlexiconMERGE-OLD.csv')
flexicon.to_csv('FlexiconMERGE.csv')
merges.to_csv('merge_matchesREMAINING.csv')
